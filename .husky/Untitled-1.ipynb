# %%
print("HI")
# Out:
# HI

# %%
from math import sqrt

result = sqrt(16)

print(result)
# Out:
# 4.0

# %%
import datetime as dt

today = dt.date.today()

print(today)
# Out:
# 2026-08-06

# %%
age = int(input("Enter age: "))

print(age)
# Out:
# 7

# %%
try:
    age = int(input("Enter your age:"))
except:
    print("Invalid age. Please enter a number.")
# Out:
# Invalid age. Please enter a number.

# %%
try:
    num = int(input("Enter a number: "))
    print(num)
except ValueError:
    print("Invalid input. Please enter a valid number.")
# Out:
# 9

# %%
def reg_stu(age):
    try:
        if age < 5:
            raise ValueError("Student is too young.")
        print("Student is registered.")
    except ValueError as e:
        print(e)
reg_stu(3)
# Out:
# Student is too young.
